# %%
import time
import matplotlib.pyplot as plt

# Fibonacci đệ quy
def fib_recursive(n):
    if n <= 1:
        return n
    return fib_recursive(n-1) + fib_recursive(n-2)

# Fibonacci lặp
def fib_iterative(n):
    a, b = 0, 1
    for i in range(n):
        a, b = b, a + b
    return a

n_values = []
recursive_times = []
iterative_times = []

# thử với nhiều giá trị n
for n in range(5, 50, 5):
    n_values.append(n)

    start = time.time()
    fib_recursive(n)
    recursive_times.append(time.time() - start)

    start = time.time()
    fib_iterative(n)
    iterative_times.append(time.time() - start)

# vẽ biểu đồ
plt.plot(n_values, recursive_times, marker='o', label="Recursive")
plt.plot(n_values, iterative_times, marker='o', label="Iterative")

plt.xlabel("n")
plt.ylabel("Execution Time (seconds)")
plt.title("23000111 - Vũ Tiến Đạt ")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 26
#      23 n_values.append(n)
#      25 start = time.time()
# ---> 26 fib_recursive(n)
#      27 recursive_times.append(time.time() - start)
#      29 start = time.time()
#
# Cell In[5], line 8, in fib_recursive(n)
#       6 if n <= 1:
#       7     return n
# ----> 8 return fib_recursive(n-1) + fib_recursive(n-2)
#
# Cell In[5], line 8, in fib_recursive(n)
#       6 if n <= 1:
#       7     return n
# ----> 8 return fib_recursive(n-1) + fib_recursive(n-2)
#
#     [... skipping similar frames: fib_recursive at line 8 (48 times)]
#
# Cell In[5], line 8, in fib_recursive(n)
#       6 if n <= 1:
#       7     return n
# ----> 8 return fib_recursive(n-1) + fib_recursive(n-2)
#
# Cell In[5], line 5, in fib_recursive(n)
#       2 import matplotlib.pyplot as plt
#       4 # Fibonacci đệ quy
# ----> 5 def fib_recursive(n):
#       6     if n <= 1:
#       7         return n
#
# KeyboardInterrupt:
